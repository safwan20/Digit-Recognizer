# %%
#for data manupilations
import pandas as pd
import numpy as np

#for images pre-processing
import cv2

#for one hot encode
from keras.utils.np_utils import to_categorical

#for model creation
import tensorflow as tf
from keras.layers import Conv2D, MaxPooling2D , Flatten, Dense, Dropout
from keras.models import Sequential
from tensorflow import keras

#to plot graphs
import matplotlib.pyplot as plt

#to convert into tensorflowjs for interference
import tensorflowjs as tfjs

# %%
train = pd.read_csv('/kaggle/input/digit-recognizer/train.csv')

# %%
x = train.iloc[:,1:].values
y = train['label'].values

# %%
plt.imshow(c[0].reshape(28,28),cmap="gray_r")

# %%
y = to_categorical(y)
x = x / 255
x = x.reshape(42000,28,28,1)

# %%
classifier = Sequential()
classifier.add(Conv2D(32,(5,5),padding="same",input_shape = (28,28,1),activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Dropout(0.2))
classifier.add(Conv2D(32,(5,5),padding="same",activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Dropout(0.2))
classifier.add(Conv2D(32,(5,5),padding="same",activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Flatten())
classifier.add(Dense(units=128,activation='relu'))
classifier.add(Dropout(0.2))
classifier.add(Dense(units=10,activation='softmax'))
classifier.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
batch_size = 32
epochs = 500
classifier.fit(x, y, batch_size=batch_size, epochs=epochs, verbose=1)

# %%
classifier

# %%
classifier.save('digit.h5')

# %%
model = keras.models.load_model('digitttt.h5')

# %%
tfjs.converters.save_keras_model(model, "models")
